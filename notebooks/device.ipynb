# %%
import torch

print(torch.__version__)
print("CUDA:", torch.cuda.is_available())
print("MPS:", torch.backends.mps.is_available())
# Out:
# 2.5.1
# CUDA: False
# MPS: True

# %%
from mlkem_gpu.device import DEVICE, print_device_info

print_device_info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.mlkem_gpu.device import DEVICE, print_device_info
#       2
#       3 print_device_info()
#
# ModuleNotFoundError: No module named 'src'
